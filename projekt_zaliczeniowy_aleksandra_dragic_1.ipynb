# %%
#Zaliczenie

# %%
import pandas as pd
zadanie = pd.read_csv('dane3.csv')
zadanie

# %%
#Część pierwsza

# %% [markdown]
# 1. Zamień skróty nazw dni tygodnia na polskie odpowiedni(pełne nazwy dni tygodnia) - kolumna created_at

# %%
zadanie['created_at'] = zadanie['created_at'].str.replace('Mon', 'Poniedziałek').str.replace('Tue', 'Wtorek').str.replace('Wed', 'Środa').str.replace('Thu', 'Czwartek'). str.replace('Fri', 'Piątek').str.replace('Sat', 'Sobota').str.replace('Sun', 'Niedziela')

# %%
zadanie

# %% [markdown]
# 2. Zamień skróty nazw miesięcy na liczbowe odpowiedniki (np Jun na 06) - kolumna user_created_at

# %%
zadanie['user_created_at'] = zadanie['user_created_at'].str.replace('Jan', '01').str.replace('Feb', '02').str.replace('Mar', '03').str.replace('Apr', '04').str.replace('May', '05').str.replace('Jun', '06').str.replace('Jul', '07').str.replace('Aug', '08').str.replace('Sep', '09').str.replace('Oct', '10').str.replace('Nov', '11').str.replace('Dec', '12')

# %%
zadanie
# Out:
#       coordinates                               created_at  \
# 0             NaN  Poniedziałek Jul 05 07:58:09 +0000 2021
# 1             NaN  Poniedziałek Jul 05 08:21:28 +0000 2021
# 2             NaN  Poniedziałek Jul 05 12:50:04 +0000 2021
# 3             NaN  Poniedziałek Jul 05 06:33:46 +0000 2021
# 4             NaN  Poniedziałek Jul 05 11:13:20 +0000 2021
# ...           ...                                      ...
# 1945          NaN         Środa Jun 30 08:10:33 +0000 2021
# 1946          NaN         Środa Jun 30 08:33:10 +0000 2021
# 1947          NaN         Środa Jun 30 07:17:38 +0000 2021
# 1948          NaN         Środa Jun 30 09:37:47 +0000 2021
# 1949          NaN         Środa Jun 30 07:54:27 +0000 2021
#
#                                              hashtags  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# ...

# %% [markdown]
# 3. Pobierz wszystkie linki do tweetów i przekaż je do listy.

# %%
tweet_urls_list = zadanie['tweet_url'].to_list()
tweet_urls_list

# %% [markdown]
# 4. Pobierz wszystkie linki znajdujące się w tweetach i przekaż je do listy (kolumna urls)

# %% [markdown]
# 5. Pobierz wszystkie linki do obrazków i przekaż je do listy (kolumna media).

# %%
image_links = data['media'].tolist()
image_links

# %% [markdown]
# 6. Usuń wszystkie słowa oznaczone jako stopwords i przekaż oczyszczony tekst do nowej kolumny o nazwie text_without_stopwords

# %%
stopwords = ['a', 'i', 'w', 'na', 'z', 'do', 'o', 'że', 'się', 'jest', 'by', 'co', 'jak', 'tego', 'czy', 'tylko']

# %%
def remove_stopwords(text):
    tokens = text.split()
    clean_tokens = [token for token in tokens if token.lower() not in stopwords]
    return ' '.join(clean_tokens)

# %%
df['text_without_stopwords'] = df['text'].apply(remove_stopwords)

# %%
print(df)

# %%
#Część druga

# %% [markdown]
# 1. Wypisz top5 tweetów z największa liczbą polubień.

# %%
top_liked_tweets = data.nlargest(5, 'favorite_count')
top_liked_tweets[['text', 'favorite_count']]
# Out:
#                                                    text  favorite_count
# 1281  Imagine pójść na pierwsza randkę z dziewczyna ...            5634
# 1074  Kalifornia kroliczkiem katastrofy klimatyzmu. ...             467
# 178   @yahabibtii Pracuje w kawiarni i nieraz jacyś ...             215
# 935   Ciekawe, czy upały i pożary w chłodnej Kanadzi...             131
# 1472           myślę, że klimat https://t.co/uIXNcsyCTW              99

# %% [markdown]
# 2. Wypisz top5 tweetów z największa liczbą retweetów.

# %%
top_retweeted_tweets = data.nlargest(5, 'retweet_count')
top_retweeted_tweets[['text', 'retweet_count']]
# Out:
#                                                   text  retweet_count
# 67   Imagine pójść na pierwsza randkę z dziewczyna ...            395
# 159  Imagine pójść na pierwsza randkę z dziewczyna ...            395
# 172  Imagine pójść na pierwsza randkę z dziewczyna ...            395
# 183  Imagine pójść na pierwsza randkę z dziewczyna ...            395
# 202  Imagine pójść na pierwsza randkę z dziewczyna ...            395

# %% [markdown]
# 3. Wyświetl tylko te tweety, które nie są uznane jako “wrażliwe” (kolumna possibly_sensitive).

# %%
non_sensitive_tweets = data[data['possibly_sensitive'] == False]
non_sensitive_tweets[['text', 'possibly_sensitive']]
# Out:
#                                                    text possibly_sensitive
# 3     AutoTweet: Dobowa suma #opad w #Polska w dniu ...              False
# 6     AutoTweet: Dobowa suma #opad w #Polska w dniu ...              False
# 7     Jaki jest klimat rynkowy?\nCo ciekawego może s...              False
# 9     AutoTweet: Temperatura powierzchni południoweg...              False
# 11    Ale mi przykro :( w sensie no gratuluję chłopa...              False
# ...                                                 ...                ...
# 1935  Zmiany klimatu. #Megatrend o potencjalnie najw...              False
# 1939  Dziś popołudniu będę panelistą na dyskusji o t...              False
# 1941  AutoTweet: Miesięczna anomalia temperatury pow...              False
# 1945  dzisiaj na śniadanie tost francuski i czarna k...              False
# 1948  Hydraty metanu to alternatywne źródło energii,...              False
#
# [502 rows x 2 columns]

# %% [markdown]
# 4. Wyświetl tweety użytkownika, który założył konto najwcześniej (spośród wszystkich użytkowników w datasecie) (kolumna user_created_at).

# %%
tweet_user = zadanie['user_created_at'].min()
tweet_user = zadanie[zadanie['user_created_at'] == tweet_user]
tweet_user.loc[:, ['user_created_at', 'text']]
# Out:
#                     user_created_at  \
# 1201  Fri 01 01 19:04:39 +0000 2021
#
#                                                    text
# 1201  @AlfaLyraeV Zdecydowanie pierwsza ma jakiś swó...

# %% [markdown]
# 5. Wyświetl tweety użytkownika. który ma najwięcej followersów.

# %%
user_with_most_followers = data.nlargest(1, 'user_followers_count')
user_with_most_followers_tweets = data[data['user_id'] == user_with_most_followers['user_id'].values[0]]
user_with_most_followers_tweets[['text', 'user_followers_count']]
# Out:
#                                                    text  user_followers_count
# 1632  Fala upałów w #Kanada i #USA. Setki ofiar hipe...                332987
# 1828  #Banki dopłacą do pieców, jeśli zdecydujemy si...                332987
# 1873  49,5 stopnia Celsjusza w mieście #Kanada. Prze...                332987

# %% [markdown]
# 6. Wyświetl tylko zweryfikowanych użytkowników (kolumna user_verified)

# %%
verified_users_tweets = data[data['user_verified'] == True]
verified_users_tweets[['text', 'user_verified']]
# Out:
#                                                    text  user_verified
# 112   Dzisiaj @donaldtusk pokazał Polakom to, co pow...           True
# 205   "Ekstremalnie wysokie temperatury". Gubernator...           True
# 403   Red. Nizinkiewicz z jednego z dzienników, twor...           True
# 463   Ciekawe, czy upały i pożary w chłodnej Kanadzi...           True
# 489   ❓ Dlaczego redukcja CO2 jest kluczowa? Jak ją ...           True
# 935   Ciekawe, czy upały i pożary w chłodnej Kanadzi...           True
# 1031  @donaldtusk @Platforma_org Kryzys klimatyczny ...           True
# 1179  Rudzińska-Bluszcz: Dla obrony środowiska najbl...           True
# 1219  Nowe produkty na giełdzie i kontraktu cPPA to ...           True
# 1238  ℹ️ Wiecie co to jest zasada 3R? Czym różni się...           True
# 1269  Nowe produkty na giełdzie i kontraktu cPPA to ...           True
# 1300  📢 Zapraszamy 9 lipca 2021 r. na drugą konferen...           True
# ...

# %% [markdown]
# 7

# %%
zadanie['day_of_week'] = zadanie['created_at']
tweets_per_day = data['day_of_week'].value_counts()
most_common_day = tweets_per_day.idxmax()
number_of_tweets = tweets_per_day.max()
most_common_day
number_of_tweets
# Out:
# 616

# %%
#Część trzecia

# %%
# !pip install spacy
# !python -m spacy download pl_core_news_sm
import spacy
nlp = spacy.load("pl_core_news_sm")

# %% [markdown]
# 1. Rozpoznaj osoby (persName) i przekaż je do kolumny o nazwie persons

# %%
def detect_pers_names(text):
    doc = nlp(text)
    pers_names = []
    for ent in doc.ents:
        if ent.label_ == "persName":
            pers_names.append(ent.text)
    return pers_names
zadanie['persons'] = zadanie['text'].apply(detect_pers_names)
zadanie

# %% [markdown]
# 2. Rozpoznaj miejsca (placeName) i przekaż je do kolumny o nazwie places

# %%
def detect_place_names(text):
    doc = nlp(text)
    place_names = []
    for ent in doc.ents:
        if ent.label_ == "placeName":
            place_names.append(ent.text)
    return place_names
zadanie['places'] = zadanie['text'].apply(detect_org_names)
zadanie
# Out:
#       coordinates                               created_at  \
# 0             NaN  Poniedziałek Jul 05 07:58:09 +0000 2021
# 1             NaN  Poniedziałek Jul 05 08:21:28 +0000 2021
# 2             NaN  Poniedziałek Jul 05 12:50:04 +0000 2021
# 3             NaN  Poniedziałek Jul 05 06:33:46 +0000 2021
# 4             NaN  Poniedziałek Jul 05 11:13:20 +0000 2021
# ...           ...                                      ...
# 1945          NaN         Środa Jun 30 08:10:33 +0000 2021
# 1946          NaN         Środa Jun 30 08:33:10 +0000 2021
# 1947          NaN         Środa Jun 30 07:17:38 +0000 2021
# 1948          NaN         Środa Jun 30 09:37:47 +0000 2021
# 1949          NaN         Środa Jun 30 07:54:27 +0000 2021
#
#                                              hashtags  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# ...

# %% [markdown]
# 3. Rozpoznaj organizacje (orgName) i przekaż je do kolumny o nazwie organizations

# %%
def detect_org_names(text):
    doc = nlp(text)
    org_names = []
    for ent in doc.ents:
        if ent.label_ == "orgName":
            org_names.append(ent.text)
    return org_names
zadanie['organizations'] = zadanie['text'].apply(detect_place_names)
zadanie
# Out:
#       coordinates                               created_at  \
# 0             NaN  Poniedziałek Jul 05 07:58:09 +0000 2021
# 1             NaN  Poniedziałek Jul 05 08:21:28 +0000 2021
# 2             NaN  Poniedziałek Jul 05 12:50:04 +0000 2021
# 3             NaN  Poniedziałek Jul 05 06:33:46 +0000 2021
# 4             NaN  Poniedziałek Jul 05 11:13:20 +0000 2021
# ...           ...                                      ...
# 1945          NaN         Środa Jun 30 08:10:33 +0000 2021
# 1946          NaN         Środa Jun 30 08:33:10 +0000 2021
# 1947          NaN         Środa Jun 30 07:17:38 +0000 2021
# 1948          NaN         Środa Jun 30 09:37:47 +0000 2021
# 1949          NaN         Środa Jun 30 07:54:27 +0000 2021
#
#                                              hashtags  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# ...

# %%
#Część czwarta

# %% [markdown]
# 1. Wykorzystując pakiet matplotlib wykonaj wykres ilustrujący liczbę tweetów per dzień tygodnia

# %%
import matplotlib.pyplot as plt

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

tweet_counts_per_day = df['created_at'].dt.day_name().value_counts().sort_index()
dni_tygodnia = list(zadanie.keys())
liczba_tweetow = list(zadanie_slownik.values())

plt.title('Liczba tweetów per dzień tygodnia')
plt.xlabel('Dzień tygodnia')
plt.ylabel('Liczba tweetów')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
